# %% [markdown]
# # Generate Seafloor Age Grids
#
# This notebook generates seafloor age grids for a specified plate reconstruction model and time interval using GPlately's `SeafloorGrid` class.
#
# **Purpose**: Create consistent seafloor age grids that align with the plate reconstruction model being used, avoiding potential mismatches between pre-computed grids and updated rotation files.
#
# **Workflow**:
# 1. Load plate reconstruction model (rotation files, topologies, static polygons)
# 2. Configure seafloor gridding parameters (time range, resolution, output directory)
# 3. Generate age grids using topological plate reconstruction
# 4. Save grids to disk in NetCDF format

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import gplately
from gplately import SeafloorGrid, auxiliary

# Suppress development warnings for cleaner output
os.environ["DISABLE_GPLATELY_DEV_WARNING"] = "true"

# %% [markdown]
# ## Configuration
#
# Set the reconstruction model, time range, and output parameters.

# %%
# Plate reconstruction model
MODEL_NAME = "Clennett2020"  # Options: "Muller2019", "Clennett2020", "Merdith2021", etc.

# Time parameters (Ma)
MIN_TIME = 0     # Present day
MAX_TIME = 170   # Maximum reconstruction age
TIME_STEP = 1    # Time increment for grid generation

# Grid resolution (degrees)
GRID_SPACING = 0.1  # 0.1 degree spacing (~11 km at equator)

# Output directory - SeafloorGrid will create subdirectories within the current working directory
# We need to set file_collection to "." and let SeafloorGrid create its default structure
OUTPUT_BASE_DIR = "."  # Current directory - SeafloorGrid creates "seafloor-grid-output/" by default
MODEL_DIR = "./data/reconstructions/"

# Ensure model directory exists
os.makedirs(MODEL_DIR, exist_ok=True)

print(f"Model: {MODEL_NAME}")
print(f"Time range: {MIN_TIME}-{MAX_TIME} Ma, step: {TIME_STEP} Myr")
print(f"Grid spacing: {GRID_SPACING}°")
print(f"SeafloorGrid will create output in: ./seafloor-grid-output/")
print(f"  → Age grids will be in: ./seafloor-grid-output/SEAFLOOR_AGE/")
# Out:
# Model: Clennett2020
# Time range: 0-170 Ma, step: 1 Myr
# Grid spacing: 0.1°
# SeafloorGrid will create output in: ./seafloor-grid-output/
#   → Age grids will be in: ./seafloor-grid-output/SEAFLOOR_AGE/

# %% [markdown]
# ## Load Plate Reconstruction Model
#
# Initialize the plate reconstruction and plotting objects using GPlately's auxiliary functions.

# %%
# Load reconstruction model using auxiliary function (cleaner than manual setup)
plate_reconstruction = auxiliary.get_plate_reconstruction(MODEL_NAME, MODEL_DIR)

# Create plotting object with geometries
gplot = auxiliary.get_gplot(MODEL_NAME, MODEL_DIR, time=MIN_TIME)

print(f"✓ Loaded {MODEL_NAME} reconstruction model")
print(f"✓ Time range available: {MIN_TIME}-{MAX_TIME} Ma")
# Out:
# ✓ Loaded Clennett2020 reconstruction model
# ✓ Time range available: 0-170 Ma

# %% [markdown]
# ## Initialize SeafloorGrid Object
#
# Configure the `SeafloorGrid` object with the reconstruction model and gridding parameters.

# %%
# Create SeafloorGrid object
# Note: file_collection="." means SeafloorGrid creates its default "seafloor-grid-output/" directory
# in the current working directory. DO NOT use a custom path as it gets concatenated incorrectly.
if __name__ == "__main__":
    seafloor_grid = SeafloorGrid(
        PlateReconstruction_object=plate_reconstruction,
        PlotTopologies_object=gplot,
        max_time=MAX_TIME,
        min_time=MIN_TIME,
        ridge_time_step=TIME_STEP,
        grid_spacing=GRID_SPACING,
        file_collection="."  # MUST be "." - SeafloorGrid will create ./seafloor-grid-output/
    )
    
    print(f"✓ SeafloorGrid initialized")
    print(f"  - Output will be in: ./seafloor-grid-output/")
    print(f"  - Age grids: ./seafloor-grid-output/SEAFLOOR_AGE/")
    print(f"  - Grid points: {int(360/GRID_SPACING)} × {int(180/GRID_SPACING)}")
    print(f"  - Time steps: {len(range(MIN_TIME, MAX_TIME + 1, TIME_STEP))}")
# Out:
# ✓ SeafloorGrid initialized
#   - Output will be in: ./seafloor-grid-output/
#   - Age grids: ./seafloor-grid-output/SEAFLOOR_AGE/
#   - Grid points: 3600 × 1800
#   - Time steps: 171

# %% [markdown]
# ## Generate Age Grids
#
# Run the topological reconstruction to generate seafloor age grids for all time steps.
#
# **Note**: This process may take considerable time depending on:
# - Time range and resolution
# - Number of CPU cores available
# - Model complexity
#
# For the Clennett2020 model at 0.1° resolution over 0-170 Ma, expect **1-3 hours** on a modern workstation.

# %%
if __name__ == "__main__":
    print("Starting seafloor grid generation...")
    print("This may take 1-3 hours depending on your system.")
    print("-" * 60)
    
    # Generate grids using topological reconstruction
    # This will create netCDF files for each time step
    seafloor_grid.reconstruct_by_topologies()
    
    print("-" * 60)
    print("✓ Grid generation complete!")
    print(f"✓ Age grids saved to: ./seafloor-grid-output/SEAFLOOR_AGE/")
# Out:
# Starting seafloor grid generation...
# This may take 1-3 hours depending on your system.
# ------------------------------------------------------------
# 2025-11-29 15:46:55 - gplately - INFO - Preparing all initial files...
# 2025-11-29 15:46:57 - gplately - INFO - Finished building initial_ocean_seed_points!
# 2025-11-29 15:46:57 - gplately - INFO - Finished building initial_ocean_seed_points!
# 2025-11-29 15:46:57 - gplately - INFO - Finished building a continental mask at 170.0 Ma!
# 2025-11-29 15:46:57 - gplately - INFO - Finished building a continental mask at 170.0 Ma!
# 2025-11-29 15:46:58 - gplately - INFO - Finished building a continental mask at 169.0 Ma!
# 2025-11-29 15:46:58 - gplately - INFO - Finished building a continental mask at 169.0 Ma!
# 2025-11-29 15:46:58 - gplately - INFO - Finished building a continental mask at 168.0 Ma!
# 2025-11-29 15:46:58 - gplately - INFO - Finished building a continental mask at 168.0 Ma!
# 2025-11-29 15:46:59 - gplately - INFO - Finished building a continental mask at 167.0 Ma!
# 2025-11-29 15:46:59 - gplately - INFO - Finished building a continental mask at 167.0 Ma!
# 2025-11-29 15:46:59 - gplately - INFO - Finished building a continental mask at 166.0 Ma!
# 2025-11-29 15:46:59 - gplately - INFO - Finished building a continental mask at 166.0 Ma!
# 2025-11-29 15:47:00 - gplately - INFO - Finished building a continental mask at 165.0 Ma!
# 2025-11-29 15:47:00 - gplately - INFO - Finished building a continental mask at 165.0 Ma!
# 2025-11-29 15:47:00 - gplately - INFO - Finished building a continental mask at 164.0 Ma!
# 2025-11-29 15:47:00 - gplately - INFO - Finished building a continental mask at 164.0 Ma!
# 2025-11-29 15:47:01 - gplately - INFO - Finished building a continental mask at 163.0 Ma!
# 2025-11-29 15:47:01 - gplately - INFO - Finished building a continental mask at 163.0 Ma!
# 2025-11-29 15:47:01 - gplately - INFO - Finished building a continental mask at 162.0 Ma!
# 2025-11-29 15:47:01 - gplately - INFO - Finished building a continental mask at 162.0 Ma!
# 2025-11-29 15:47:02 - gplately - INFO - Finished building a continental mask at 161.0 Ma!
# 2025-11-29 15:47:02 - gplately - INFO - Finished building a continental mask at 161.0 Ma!
# 2025-11-29 15:47:02 - gplately - INFO - Finished building a continental mask at 160.0 Ma!
# 2025-11-29 15:47:02 - gplately - INFO - Finished building a continental mask at 160.0 Ma!
# 2025-11-29 15:47:03 - gplately - INFO - Finished building a continental mask at 159.0 Ma!
# 2025-11-29 15:47:03 - gplately - INFO - Finished building a continental mask at 159.0 Ma!
# 2025-11-29 15:47:03 - gplately - INFO - Finished building a continental mask at 158.0 Ma!
# 2025-11-29 15:47:03 - gplately - INFO - Finished building a continental mask at 158.0 Ma!
# 2025-11-29 15:47:04 - gplately - INFO - Finished building a continental mask at 157.0 Ma!
# 2025-11-29 15:47:04 - gplately - INFO - Finished building a continental mask at 157.0 Ma!
# 2025-11-29 15:47:04 - gplately - INFO - Finished building a continental mask at 156.0 Ma!
# 2025-11-29 15:47:04 - gplately - INFO - Finished building a continental mask at 156.0 Ma!
# 2025-11-29 15:47:05 - gplately - INFO - Finished building a continental mask at 155.0 Ma!
# 2025-11-29 15:47:05 - gplately - INFO - Finished building a continental mask at 155.0 Ma!
# 2025-11-29 15:47:05 - gplately - INFO - Finished building a continental mask at 154.0 Ma!
# 2025-11-29 15:47:05 - gplately - INFO - Finished building a continental mask at 154.0 Ma!
# 2025-11-29 15:47:06 - gplately - INFO - Finished building a continental mask at 153.0 Ma!
# 2025-11-29 15:47:06 - gplately - INFO - Finished building a continental mask at 153.0 Ma!
# 2025-11-29 15:47:06 - gplately - INFO - Finished building a continental mask at 152.0 Ma!
# 2025-11-29 15:47:06 - gplately - INFO - Finished building a continental mask at 152.0 Ma!
# 2025-11-29 15:47:07 - gplately - INFO - Finished building a continental mask at 151.0 Ma!
# 2025-11-29 15:47:07 - gplately - INFO - Finished building a continental mask at 151.0 Ma!
# 2025-11-29 15:47:07 - gplately - INFO - Finished building a continental mask at 150.0 Ma!
# 2025-11-29 15:47:07 - gplately - INFO - Finished building a continental mask at 150.0 Ma!
# 2025-11-29 15:47:08 - gplately - INFO - Finished building a continental mask at 149.0 Ma!
# 2025-11-29 15:47:08 - gplately - INFO - Finished building a continental mask at 149.0 Ma!
# 2025-11-29 15:47:08 - gplately - INFO - Finished building a continental mask at 148.0 Ma!
# 2025-11-29 15:47:08 - gplately - INFO - Finished building a continental mask at 148.0 Ma!
# 2025-11-29 15:47:09 - gplately - INFO - Finished building a continental mask at 147.0 Ma!
# 2025-11-29 15:47:09 - gplately - INFO - Finished building a continental mask at 147.0 Ma!
# 2025-11-29 15:47:09 - gplately - INFO - Finished building a continental mask at 146.0 Ma!
# 2025-11-29 15:47:09 - gplately - INFO - Finished building a continental mask at 146.0 Ma!
# 2025-11-29 15:47:10 - gplately - INFO - Finished building a continental mask at 145.0 Ma!
# 2025-11-29 15:47:10 - gplately - INFO - Finished building a continental mask at 145.0 Ma!
# 2025-11-29 15:47:10 - gplately - INFO - Finished building a continental mask at 144.0 Ma!
# 2025-11-29 15:47:10 - gplately - INFO - Finished building a continental mask at 144.0 Ma!
# 2025-11-29 15:47:11 - gplately - INFO - Finished building a continental mask at 143.0 Ma!
# 2025-11-29 15:47:11 - gplately - INFO - Finished building a continental mask at 143.0 Ma!
# 2025-11-29 15:47:12 - gplately - INFO - Finished building a continental mask at 142.0 Ma!
# 2025-11-29 15:47:12 - gplately - INFO - Finished building a continental mask at 142.0 Ma!
# 2025-11-29 15:47:13 - gplately - INFO - Finished building a continental mask at 141.0 Ma!
# 2025-11-29 15:47:13 - gplately - INFO - Finished building a continental mask at 141.0 Ma!
# 2025-11-29 15:47:14 - gplately - INFO - Finished building a continental mask at 140.0 Ma!
# 2025-11-29 15:47:14 - gplately - INFO - Finished building a continental mask at 140.0 Ma!
# 2025-11-29 15:47:15 - gplately - INFO - Finished building a continental mask at 139.0 Ma!
# 2025-11-29 15:47:15 - gplately - INFO - Finished building a continental mask at 139.0 Ma!
# 2025-11-29 15:47:16 - gplately - INFO - Finished building a continental mask at 138.0 Ma!
# 2025-11-29 15:47:16 - gplately - INFO - Finished building a continental mask at 138.0 Ma!
# 2025-11-29 15:47:17 - gplately - INFO - Finished building a continental mask at 137.0 Ma!
# 2025-11-29 15:47:17 - gplately - INFO - Finished building a continental mask at 137.0 Ma!
# 2025-11-29 15:47:18 - gplately - INFO - Finished building a continental mask at 136.0 Ma!
# 2025-11-29 15:47:18 - gplately - INFO - Finished building a continental mask at 136.0 Ma!
# 2025-11-29 15:47:19 - gplately - INFO - Finished building a continental mask at 135.0 Ma!
# 2025-11-29 15:47:19 - gplately - INFO - Finished building a continental mask at 135.0 Ma!
# 2025-11-29 15:47:20 - gplately - INFO - Finished building a continental mask at 134.0 Ma!
# 2025-11-29 15:47:20 - gplately - INFO - Finished building a continental mask at 134.0 Ma!
# 2025-11-29 15:47:21 - gplately - INFO - Finished building a continental mask at 133.0 Ma!
# 2025-11-29 15:47:21 - gplately - INFO - Finished building a continental mask at 133.0 Ma!
# 2025-11-29 15:47:22 - gplately - INFO - Finished building a continental mask at 132.0 Ma!
# 2025-11-29 15:47:22 - gplately - INFO - Finished building a continental mask at 132.0 Ma!
# 2025-11-29 15:47:23 - gplately - INFO - Finished building a continental mask at 131.0 Ma!
# 2025-11-29 15:47:23 - gplately - INFO - Finished building a continental mask at 131.0 Ma!
# 2025-11-29 15:47:24 - gplately - INFO - Finished building a continental mask at 130.0 Ma!
# 2025-11-29 15:47:24 - gplately - INFO - Finished building a continental mask at 130.0 Ma!
# 2025-11-29 15:47:25 - gplately - INFO - Finished building a continental mask at 129.0 Ma!
# 2025-11-29 15:47:25 - gplately - INFO - Finished building a continental mask at 129.0 Ma!
# 2025-11-29 15:47:26 - gplately - INFO - Finished building a continental mask at 128.0 Ma!
# 2025-11-29 15:47:26 - gplately - INFO - Finished building a continental mask at 128.0 Ma!
# 2025-11-29 15:47:27 - gplately - INFO - Finished building a continental mask at 127.0 Ma!
# 2025-11-29 15:47:27 - gplately - INFO - Finished building a continental mask at 127.0 Ma!
# 2025-11-29 15:47:28 - gplately - INFO - Finished building a continental mask at 126.0 Ma!
# 2025-11-29 15:47:28 - gplately - INFO - Finished building a continental mask at 126.0 Ma!
# 2025-11-29 15:47:29 - gplately - INFO - Finished building a continental mask at 125.0 Ma!
# 2025-11-29 15:47:29 - gplately - INFO - Finished building a continental mask at 125.0 Ma!
# 2025-11-29 15:47:30 - gplately - INFO - Finished building a continental mask at 124.0 Ma!
# 2025-11-29 15:47:30 - gplately - INFO - Finished building a continental mask at 124.0 Ma!
# 2025-11-29 15:47:31 - gplately - INFO - Finished building a continental mask at 123.0 Ma!
# 2025-11-29 15:47:31 - gplately - INFO - Finished building a continental mask at 123.0 Ma!
# 2025-11-29 15:47:32 - gplately - INFO - Finished building a continental mask at 122.0 Ma!
# 2025-11-29 15:47:32 - gplately - INFO - Finished building a continental mask at 122.0 Ma!
# 2025-11-29 15:47:33 - gplately - INFO - Finished building a continental mask at 121.0 Ma!
# 2025-11-29 15:47:33 - gplately - INFO - Finished building a continental mask at 121.0 Ma!
# 2025-11-29 15:47:34 - gplately - INFO - Finished building a continental mask at 120.0 Ma!
# 2025-11-29 15:47:34 - gplately - INFO - Finished building a continental mask at 120.0 Ma!
# 2025-11-29 15:47:35 - gplately - INFO - Finished building a continental mask at 119.0 Ma!
# 2025-11-29 15:47:35 - gplately - INFO - Finished building a continental mask at 119.0 Ma!
# 2025-11-29 15:47:36 - gplately - INFO - Finished building a continental mask at 118.0 Ma!
# 2025-11-29 15:47:36 - gplately - INFO - Finished building a continental mask at 118.0 Ma!
# 2025-11-29 15:47:38 - gplately - INFO - Finished building a continental mask at 117.0 Ma!
# 2025-11-29 15:47:38 - gplately - INFO - Finished building a continental mask at 117.0 Ma!
# 2025-11-29 15:47:39 - gplately - INFO - Finished building a continental mask at 116.0 Ma!
# 2025-11-29 15:47:39 - gplately - INFO - Finished building a continental mask at 116.0 Ma!
# 2025-11-29 15:47:39 - gplately - INFO - Finished building a continental mask at 115.0 Ma!
# 2025-11-29 15:47:39 - gplately - INFO - Finished building a continental mask at 115.0 Ma!
# 2025-11-29 15:47:40 - gplately - INFO - Finished building a continental mask at 114.0 Ma!
# 2025-11-29 15:47:40 - gplately - INFO - Finished building a continental mask at 114.0 Ma!
# 2025-11-29 15:47:41 - gplately - INFO - Finished building a continental mask at 113.0 Ma!
# 2025-11-29 15:47:41 - gplately - INFO - Finished building a continental mask at 113.0 Ma!
# 2025-11-29 15:47:42 - gplately - INFO - Finished building a continental mask at 112.0 Ma!
# 2025-11-29 15:47:42 - gplately - INFO - Finished building a continental mask at 112.0 Ma!
# 2025-11-29 15:47:43 - gplately - INFO - Finished building a continental mask at 111.0 Ma!
# 2025-11-29 15:47:43 - gplately - INFO - Finished building a continental mask at 111.0 Ma!
# 2025-11-29 15:47:43 - gplately - INFO - Finished building a continental mask at 110.0 Ma!
# 2025-11-29 15:47:43 - gplately - INFO - Finished building a continental mask at 110.0 Ma!
# 2025-11-29 15:47:44 - gplately - INFO - Finished building a continental mask at 109.0 Ma!
# 2025-11-29 15:47:44 - gplately - INFO - Finished building a continental mask at 109.0 Ma!
# 2025-11-29 15:47:45 - gplately - INFO - Finished building a continental mask at 108.0 Ma!
# 2025-11-29 15:47:45 - gplately - INFO - Finished building a continental mask at 108.0 Ma!
# 2025-11-29 15:47:46 - gplately - INFO - Finished building a continental mask at 107.0 Ma!
# 2025-11-29 15:47:46 - gplately - INFO - Finished building a continental mask at 107.0 Ma!
# 2025-11-29 15:47:47 - gplately - INFO - Finished building a continental mask at 106.0 Ma!
# 2025-11-29 15:47:47 - gplately - INFO - Finished building a continental mask at 106.0 Ma!
# 2025-11-29 15:47:47 - gplately - INFO - Finished building a continental mask at 105.0 Ma!
# 2025-11-29 15:47:47 - gplately - INFO - Finished building a continental mask at 105.0 Ma!
# 2025-11-29 15:47:48 - gplately - INFO - Finished building a continental mask at 104.0 Ma!
# 2025-11-29 15:47:48 - gplately - INFO - Finished building a continental mask at 104.0 Ma!
# 2025-11-29 15:47:49 - gplately - INFO - Finished building a continental mask at 103.0 Ma!
# 2025-11-29 15:47:49 - gplately - INFO - Finished building a continental mask at 103.0 Ma!
# 2025-11-29 15:47:50 - gplately - INFO - Finished building a continental mask at 102.0 Ma!
# 2025-11-29 15:47:50 - gplately - INFO - Finished building a continental mask at 102.0 Ma!
# 2025-11-29 15:47:51 - gplately - INFO - Finished building a continental mask at 101.0 Ma!
# 2025-11-29 15:47:51 - gplately - INFO - Finished building a continental mask at 101.0 Ma!
# 2025-11-29 15:47:51 - gplately - INFO - Finished building a continental mask at 100.0 Ma!
# 2025-11-29 15:47:51 - gplately - INFO - Finished building a continental mask at 100.0 Ma!
# 2025-11-29 15:47:52 - gplately - INFO - Finished building a continental mask at 99.0 Ma!
# 2025-11-29 15:47:52 - gplately - INFO - Finished building a continental mask at 99.0 Ma!
# 2025-11-29 15:47:53 - gplately - INFO - Finished building a continental mask at 98.0 Ma!
# 2025-11-29 15:47:53 - gplately - INFO - Finished building a continental mask at 98.0 Ma!
# 2025-11-29 15:47:54 - gplately - INFO - Finished building a continental mask at 97.0 Ma!
# 2025-11-29 15:47:54 - gplately - INFO - Finished building a continental mask at 97.0 Ma!
# 2025-11-29 15:47:55 - gplately - INFO - Finished building a continental mask at 96.0 Ma!
# 2025-11-29 15:47:55 - gplately - INFO - Finished building a continental mask at 96.0 Ma!
# 2025-11-29 15:47:56 - gplately - INFO - Finished building a continental mask at 95.0 Ma!
# 2025-11-29 15:47:56 - gplately - INFO - Finished building a continental mask at 95.0 Ma!
# 2025-11-29 15:47:57 - gplately - INFO - Finished building a continental mask at 94.0 Ma!
# 2025-11-29 15:47:57 - gplately - INFO - Finished building a continental mask at 94.0 Ma!
# 2025-11-29 15:47:58 - gplately - INFO - Finished building a continental mask at 93.0 Ma!
# 2025-11-29 15:47:58 - gplately - INFO - Finished building a continental mask at 93.0 Ma!
# 2025-11-29 15:47:59 - gplately - INFO - Finished building a continental mask at 92.0 Ma!
# 2025-11-29 15:47:59 - gplately - INFO - Finished building a continental mask at 92.0 Ma!
# 2025-11-29 15:48:00 - gplately - INFO - Finished building a continental mask at 91.0 Ma!
# 2025-11-29 15:48:00 - gplately - INFO - Finished building a continental mask at 91.0 Ma!
# 2025-11-29 15:48:01 - gplately - INFO - Finished building a continental mask at 90.0 Ma!
# 2025-11-29 15:48:01 - gplately - INFO - Finished building a continental mask at 90.0 Ma!
# 2025-11-29 15:48:02 - gplately - INFO - Finished building a continental mask at 89.0 Ma!
# 2025-11-29 15:48:02 - gplately - INFO - Finished building a continental mask at 89.0 Ma!
# 2025-11-29 15:48:03 - gplately - INFO - Finished building a continental mask at 88.0 Ma!
# 2025-11-29 15:48:03 - gplately - INFO - Finished building a continental mask at 88.0 Ma!
# 2025-11-29 15:48:04 - gplately - INFO - Finished building a continental mask at 87.0 Ma!
# 2025-11-29 15:48:04 - gplately - INFO - Finished building a continental mask at 87.0 Ma!
# 2025-11-29 15:48:05 - gplately - INFO - Finished building a continental mask at 86.0 Ma!
# 2025-11-29 15:48:05 - gplately - INFO - Finished building a continental mask at 86.0 Ma!
# 2025-11-29 15:48:05 - gplately - INFO - Finished building a continental mask at 85.0 Ma!
# 2025-11-29 15:48:05 - gplately - INFO - Finished building a continental mask at 85.0 Ma!
# 2025-11-29 15:48:06 - gplately - INFO - Finished building a continental mask at 84.0 Ma!
# 2025-11-29 15:48:06 - gplately - INFO - Finished building a continental mask at 84.0 Ma!
# 2025-11-29 15:48:07 - gplately - INFO - Finished building a continental mask at 83.0 Ma!
# 2025-11-29 15:48:07 - gplately - INFO - Finished building a continental mask at 83.0 Ma!
# 2025-11-29 15:48:08 - gplately - INFO - Finished building a continental mask at 82.0 Ma!
# 2025-11-29 15:48:08 - gplately - INFO - Finished building a continental mask at 82.0 Ma!
# 2025-11-29 15:48:09 - gplately - INFO - Finished building a continental mask at 81.0 Ma!
# 2025-11-29 15:48:09 - gplately - INFO - Finished building a continental mask at 81.0 Ma!
# 2025-11-29 15:48:09 - gplately - INFO - Finished building a continental mask at 80.0 Ma!
# 2025-11-29 15:48:09 - gplately - INFO - Finished building a continental mask at 80.0 Ma!
# 2025-11-29 15:48:10 - gplately - INFO - Finished building a continental mask at 79.0 Ma!
# 2025-11-29 15:48:10 - gplately - INFO - Finished building a continental mask at 79.0 Ma!
# 2025-11-29 15:48:11 - gplately - INFO - Finished building a continental mask at 78.0 Ma!
# 2025-11-29 15:48:11 - gplately - INFO - Finished building a continental mask at 78.0 Ma!
# 2025-11-29 15:48:12 - gplately - INFO - Finished building a continental mask at 77.0 Ma!
# 2025-11-29 15:48:12 - gplately - INFO - Finished building a continental mask at 77.0 Ma!
# 2025-11-29 15:48:13 - gplately - INFO - Finished building a continental mask at 76.0 Ma!
# 2025-11-29 15:48:13 - gplately - INFO - Finished building a continental mask at 76.0 Ma!
# 2025-11-29 15:48:13 - gplately - INFO - Finished building a continental mask at 75.0 Ma!
# 2025-11-29 15:48:13 - gplately - INFO - Finished building a continental mask at 75.0 Ma!
# 2025-11-29 15:48:14 - gplately - INFO - Finished building a continental mask at 74.0 Ma!
# 2025-11-29 15:48:14 - gplately - INFO - Finished building a continental mask at 74.0 Ma!
# 2025-11-29 15:48:15 - gplately - INFO - Finished building a continental mask at 73.0 Ma!
# 2025-11-29 15:48:15 - gplately - INFO - Finished building a continental mask at 73.0 Ma!
# 2025-11-29 15:48:15 - gplately - INFO - Finished building a continental mask at 72.0 Ma!
# 2025-11-29 15:48:15 - gplately - INFO - Finished building a continental mask at 72.0 Ma!
# 2025-11-29 15:48:16 - gplately - INFO - Finished building a continental mask at 71.0 Ma!
# 2025-11-29 15:48:16 - gplately - INFO - Finished building a continental mask at 71.0 Ma!
# 2025-11-29 15:48:17 - gplately - INFO - Finished building a continental mask at 70.0 Ma!
# 2025-11-29 15:48:17 - gplately - INFO - Finished building a continental mask at 70.0 Ma!
# 2025-11-29 15:48:18 - gplately - INFO - Finished building a continental mask at 69.0 Ma!
# 2025-11-29 15:48:18 - gplately - INFO - Finished building a continental mask at 69.0 Ma!
# 2025-11-29 15:48:19 - gplately - INFO - Finished building a continental mask at 68.0 Ma!
# 2025-11-29 15:48:19 - gplately - INFO - Finished building a continental mask at 68.0 Ma!
# 2025-11-29 15:48:19 - gplately - INFO - Finished building a continental mask at 67.0 Ma!
# 2025-11-29 15:48:19 - gplately - INFO - Finished building a continental mask at 67.0 Ma!
# 2025-11-29 15:48:20 - gplately - INFO - Finished building a continental mask at 66.0 Ma!
# 2025-11-29 15:48:20 - gplately - INFO - Finished building a continental mask at 66.0 Ma!
# 2025-11-29 15:48:21 - gplately - INFO - Finished building a continental mask at 65.0 Ma!
# 2025-11-29 15:48:21 - gplately - INFO - Finished building a continental mask at 65.0 Ma!
# 2025-11-29 15:48:22 - gplately - INFO - Finished building a continental mask at 64.0 Ma!
# 2025-11-29 15:48:22 - gplately - INFO - Finished building a continental mask at 64.0 Ma!
# 2025-11-29 15:48:22 - gplately - INFO - Finished building a continental mask at 63.0 Ma!
# 2025-11-29 15:48:22 - gplately - INFO - Finished building a continental mask at 63.0 Ma!
# 2025-11-29 15:48:23 - gplately - INFO - Finished building a continental mask at 62.0 Ma!
# 2025-11-29 15:48:23 - gplately - INFO - Finished building a continental mask at 62.0 Ma!
# 2025-11-29 15:48:24 - gplately - INFO - Finished building a continental mask at 61.0 Ma!
# 2025-11-29 15:48:24 - gplately - INFO - Finished building a continental mask at 61.0 Ma!
# 2025-11-29 15:48:25 - gplately - INFO - Finished building a continental mask at 60.0 Ma!
# 2025-11-29 15:48:25 - gplately - INFO - Finished building a continental mask at 60.0 Ma!
# 2025-11-29 15:48:25 - gplately - INFO - Finished building a continental mask at 59.0 Ma!
# 2025-11-29 15:48:25 - gplately - INFO - Finished building a continental mask at 59.0 Ma!
# 2025-11-29 15:48:26 - gplately - INFO - Finished building a continental mask at 58.0 Ma!
# 2025-11-29 15:48:26 - gplately - INFO - Finished building a continental mask at 58.0 Ma!
# 2025-11-29 15:48:27 - gplately - INFO - Finished building a continental mask at 57.0 Ma!
# 2025-11-29 15:48:27 - gplately - INFO - Finished building a continental mask at 57.0 Ma!
# 2025-11-29 15:48:28 - gplately - INFO - Finished building a continental mask at 56.0 Ma!
# 2025-11-29 15:48:28 - gplately - INFO - Finished building a continental mask at 56.0 Ma!
# 2025-11-29 15:48:28 - gplately - INFO - Finished building a continental mask at 55.0 Ma!
# 2025-11-29 15:48:28 - gplately - INFO - Finished building a continental mask at 55.0 Ma!
# 2025-11-29 15:48:29 - gplately - INFO - Finished building a continental mask at 54.0 Ma!
# 2025-11-29 15:48:29 - gplately - INFO - Finished building a continental mask at 54.0 Ma!
# 2025-11-29 15:48:30 - gplately - INFO - Finished building a continental mask at 53.0 Ma!
# 2025-11-29 15:48:30 - gplately - INFO - Finished building a continental mask at 53.0 Ma!
# 2025-11-29 15:48:31 - gplately - INFO - Finished building a continental mask at 52.0 Ma!
# 2025-11-29 15:48:31 - gplately - INFO - Finished building a continental mask at 52.0 Ma!
# 2025-11-29 15:48:31 - gplately - INFO - Finished building a continental mask at 51.0 Ma!
# 2025-11-29 15:48:31 - gplately - INFO - Finished building a continental mask at 51.0 Ma!
# 2025-11-29 15:48:32 - gplately - INFO - Finished building a continental mask at 50.0 Ma!
# 2025-11-29 15:48:32 - gplately - INFO - Finished building a continental mask at 50.0 Ma!
# 2025-11-29 15:48:33 - gplately - INFO - Finished building a continental mask at 49.0 Ma!
# 2025-11-29 15:48:33 - gplately - INFO - Finished building a continental mask at 49.0 Ma!
# 2025-11-29 15:48:34 - gplately - INFO - Finished building a continental mask at 48.0 Ma!
# 2025-11-29 15:48:34 - gplately - INFO - Finished building a continental mask at 48.0 Ma!
# 2025-11-29 15:48:35 - gplately - INFO - Finished building a continental mask at 47.0 Ma!
# 2025-11-29 15:48:35 - gplately - INFO - Finished building a continental mask at 47.0 Ma!
# 2025-11-29 15:48:36 - gplately - INFO - Finished building a continental mask at 46.0 Ma!
# 2025-11-29 15:48:36 - gplately - INFO - Finished building a continental mask at 46.0 Ma!
# 2025-11-29 15:48:37 - gplately - INFO - Finished building a continental mask at 45.0 Ma!
# 2025-11-29 15:48:37 - gplately - INFO - Finished building a continental mask at 45.0 Ma!
# 2025-11-29 15:48:37 - gplately - INFO - Finished building a continental mask at 44.0 Ma!
# 2025-11-29 15:48:37 - gplately - INFO - Finished building a continental mask at 44.0 Ma!
# 2025-11-29 15:48:38 - gplately - INFO - Finished building a continental mask at 43.0 Ma!
# 2025-11-29 15:48:38 - gplately - INFO - Finished building a continental mask at 43.0 Ma!
# 2025-11-29 15:48:39 - gplately - INFO - Finished building a continental mask at 42.0 Ma!
# 2025-11-29 15:48:39 - gplately - INFO - Finished building a continental mask at 42.0 Ma!
# 2025-11-29 15:48:40 - gplately - INFO - Finished building a continental mask at 41.0 Ma!
# 2025-11-29 15:48:40 - gplately - INFO - Finished building a continental mask at 41.0 Ma!
# 2025-11-29 15:48:41 - gplately - INFO - Finished building a continental mask at 40.0 Ma!
# 2025-11-29 15:48:41 - gplately - INFO - Finished building a continental mask at 40.0 Ma!
# 2025-11-29 15:48:42 - gplately - INFO - Finished building a continental mask at 39.0 Ma!
# 2025-11-29 15:48:42 - gplately - INFO - Finished building a continental mask at 39.0 Ma!
# 2025-11-29 15:48:43 - gplately - INFO - Finished building a continental mask at 38.0 Ma!
# 2025-11-29 15:48:43 - gplately - INFO - Finished building a continental mask at 38.0 Ma!
# 2025-11-29 15:48:44 - gplately - INFO - Finished building a continental mask at 37.0 Ma!
# 2025-11-29 15:48:44 - gplately - INFO - Finished building a continental mask at 37.0 Ma!
# 2025-11-29 15:48:45 - gplately - INFO - Finished building a continental mask at 36.0 Ma!
# 2025-11-29 15:48:45 - gplately - INFO - Finished building a continental mask at 36.0 Ma!
# 2025-11-29 15:48:45 - gplately - INFO - Finished building a continental mask at 35.0 Ma!
# 2025-11-29 15:48:45 - gplately - INFO - Finished building a continental mask at 35.0 Ma!
# 2025-11-29 15:48:46 - gplately - INFO - Finished building a continental mask at 34.0 Ma!
# 2025-11-29 15:48:46 - gplately - INFO - Finished building a continental mask at 34.0 Ma!
# 2025-11-29 15:48:47 - gplately - INFO - Finished building a continental mask at 33.0 Ma!
# 2025-11-29 15:48:47 - gplately - INFO - Finished building a continental mask at 33.0 Ma!
# 2025-11-29 15:48:47 - gplately - INFO - Finished building a continental mask at 32.0 Ma!
# 2025-11-29 15:48:47 - gplately - INFO - Finished building a continental mask at 32.0 Ma!
# 2025-11-29 15:48:48 - gplately - INFO - Finished building a continental mask at 31.0 Ma!
# 2025-11-29 15:48:48 - gplately - INFO - Finished building a continental mask at 31.0 Ma!
# 2025-11-29 15:48:49 - gplately - INFO - Finished building a continental mask at 30.0 Ma!
# 2025-11-29 15:48:49 - gplately - INFO - Finished building a continental mask at 30.0 Ma!
# 2025-11-29 15:48:49 - gplately - INFO - Finished building a continental mask at 29.0 Ma!
# 2025-11-29 15:48:49 - gplately - INFO - Finished building a continental mask at 29.0 Ma!
# 2025-11-29 15:48:50 - gplately - INFO - Finished building a continental mask at 28.0 Ma!
# 2025-11-29 15:48:50 - gplately - INFO - Finished building a continental mask at 28.0 Ma!
# 2025-11-29 15:48:51 - gplately - INFO - Finished building a continental mask at 27.0 Ma!
# 2025-11-29 15:48:51 - gplately - INFO - Finished building a continental mask at 27.0 Ma!
# 2025-11-29 15:48:51 - gplately - INFO - Finished building a continental mask at 26.0 Ma!
# 2025-11-29 15:48:51 - gplately - INFO - Finished building a continental mask at 26.0 Ma!
# 2025-11-29 15:48:52 - gplately - INFO - Finished building a continental mask at 25.0 Ma!
# 2025-11-29 15:48:52 - gplately - INFO - Finished building a continental mask at 25.0 Ma!
# 2025-11-29 15:48:53 - gplately - INFO - Finished building a continental mask at 24.0 Ma!
# 2025-11-29 15:48:53 - gplately - INFO - Finished building a continental mask at 24.0 Ma!
# 2025-11-29 15:48:53 - gplately - INFO - Finished building a continental mask at 23.0 Ma!
# 2025-11-29 15:48:53 - gplately - INFO - Finished building a continental mask at 23.0 Ma!
# 2025-11-29 15:48:54 - gplately - INFO - Finished building a continental mask at 22.0 Ma!
# 2025-11-29 15:48:54 - gplately - INFO - Finished building a continental mask at 22.0 Ma!
# 2025-11-29 15:48:55 - gplately - INFO - Finished building a continental mask at 21.0 Ma!
# 2025-11-29 15:48:55 - gplately - INFO - Finished building a continental mask at 21.0 Ma!
# 2025-11-29 15:48:55 - gplately - INFO - Finished building a continental mask at 20.0 Ma!
# 2025-11-29 15:48:55 - gplately - INFO - Finished building a continental mask at 20.0 Ma!
# 2025-11-29 15:48:56 - gplately - INFO - Finished building a continental mask at 19.0 Ma!
# 2025-11-29 15:48:56 - gplately - INFO - Finished building a continental mask at 19.0 Ma!
# 2025-11-29 15:48:57 - gplately - INFO - Finished building a continental mask at 18.0 Ma!
# 2025-11-29 15:48:57 - gplately - INFO - Finished building a continental mask at 18.0 Ma!
# 2025-11-29 15:48:57 - gplately - INFO - Finished building a continental mask at 17.0 Ma!
# 2025-11-29 15:48:57 - gplately - INFO - Finished building a continental mask at 17.0 Ma!
# 2025-11-29 15:48:58 - gplately - INFO - Finished building a continental mask at 16.0 Ma!
# 2025-11-29 15:48:58 - gplately - INFO - Finished building a continental mask at 16.0 Ma!
# 2025-11-29 15:48:59 - gplately - INFO - Finished building a continental mask at 15.0 Ma!
# 2025-11-29 15:48:59 - gplately - INFO - Finished building a continental mask at 15.0 Ma!
# 2025-11-29 15:48:59 - gplately - INFO - Finished building a continental mask at 14.0 Ma!
# 2025-11-29 15:48:59 - gplately - INFO - Finished building a continental mask at 14.0 Ma!
# 2025-11-29 15:49:00 - gplately - INFO - Finished building a continental mask at 13.0 Ma!
# 2025-11-29 15:49:00 - gplately - INFO - Finished building a continental mask at 13.0 Ma!
# 2025-11-29 15:49:01 - gplately - INFO - Finished building a continental mask at 12.0 Ma!
# 2025-11-29 15:49:01 - gplately - INFO - Finished building a continental mask at 12.0 Ma!
# 2025-11-29 15:49:01 - gplately - INFO - Finished building a continental mask at 11.0 Ma!
# 2025-11-29 15:49:01 - gplately - INFO - Finished building a continental mask at 11.0 Ma!
# 2025-11-29 15:49:02 - gplately - INFO - Finished building a continental mask at 10.0 Ma!
# 2025-11-29 15:49:02 - gplately - INFO - Finished building a continental mask at 10.0 Ma!
# 2025-11-29 15:49:03 - gplately - INFO - Finished building a continental mask at 9.0 Ma!
# 2025-11-29 15:49:03 - gplately - INFO - Finished building a continental mask at 9.0 Ma!
# 2025-11-29 15:49:03 - gplately - INFO - Finished building a continental mask at 8.0 Ma!
# 2025-11-29 15:49:03 - gplately - INFO - Finished building a continental mask at 8.0 Ma!
# 2025-11-29 15:49:04 - gplately - INFO - Finished building a continental mask at 7.0 Ma!
# 2025-11-29 15:49:04 - gplately - INFO - Finished building a continental mask at 7.0 Ma!
# 2025-11-29 15:49:05 - gplately - INFO - Finished building a continental mask at 6.0 Ma!
# 2025-11-29 15:49:05 - gplately - INFO - Finished building a continental mask at 6.0 Ma!
# 2025-11-29 15:49:05 - gplately - INFO - Finished building a continental mask at 5.0 Ma!
# 2025-11-29 15:49:05 - gplately - INFO - Finished building a continental mask at 5.0 Ma!
# 2025-11-29 15:49:06 - gplately - INFO - Finished building a continental mask at 4.0 Ma!
# 2025-11-29 15:49:06 - gplately - INFO - Finished building a continental mask at 4.0 Ma!
# 2025-11-29 15:49:07 - gplately - INFO - Finished building a continental mask at 3.0 Ma!
# 2025-11-29 15:49:07 - gplately - INFO - Finished building a continental mask at 3.0 Ma!
# 2025-11-29 15:49:08 - gplately - INFO - Finished building a continental mask at 2.0 Ma!
# 2025-11-29 15:49:08 - gplately - INFO - Finished building a continental mask at 2.0 Ma!
# 2025-11-29 15:49:08 - gplately - INFO - Finished building a continental mask at 1.0 Ma!
# 2025-11-29 15:49:08 - gplately - INFO - Finished building a continental mask at 1.0 Ma!
# 2025-11-29 15:49:09 - gplately - INFO - Finished building a continental mask at 0.0 Ma!
# 2025-11-29 15:49:09 - gplately - INFO - Finished building a continental mask at 0.0 Ma!
# 2025-11-29 15:49:32 - gplately - INFO - Finished building MOR seedpoints at 169.0 Ma!
# 2025-11-29 15:49:32 - gplately - INFO - Finished building MOR seedpoints at 168.0 Ma!
# 2025-11-29 15:49:32 - gplately - INFO - Finished building MOR seedpoints at 167.0 Ma!
# 2025-11-29 15:49:32 - gplately - INFO - Finished building MOR seedpoints at 166.0 Ma!
# 2025-11-29 15:49:32 - gplately - INFO - Finished building MOR seedpoints at 165.0 Ma!
# 2025-11-29 15:49:41 - gplately - INFO - Finished building MOR seedpoints at 164.0 Ma!
# 2025-11-29 15:49:41 - gplately - INFO - Finished building MOR seedpoints at 163.0 Ma!
# 2025-11-29 15:49:41 - gplately - INFO - Finished building MOR seedpoints at 162.0 Ma!
# 2025-11-29 15:49:41 - gplately - INFO - Finished building MOR seedpoints at 161.0 Ma!
# 2025-11-29 15:49:41 - gplately - INFO - Finished building MOR seedpoints at 160.0 Ma!
# 2025-11-29 15:49:32 - gplately - INFO - Finished building MOR seedpoints at 169.0 Ma!
# 2025-11-29 15:49:32 - gplately - INFO - Finished building MOR seedpoints at 168.0 Ma!
# 2025-11-29 15:49:32 - gplately - INFO - Finished building MOR seedpoints at 167.0 Ma!
# 2025-11-29 15:49:32 - gplately - INFO - Finished building MOR seedpoints at 166.0 Ma!
# 2025-11-29 15:49:32 - gplately - INFO - Finished building MOR seedpoints at 165.0 Ma!
# 2025-11-29 15:49:41 - gplately - INFO - Finished building MOR seedpoints at 164.0 Ma!
# 2025-11-29 15:49:41 - gplately - INFO - Finished building MOR seedpoints at 163.0 Ma!
# 2025-11-29 15:49:41 - gplately - INFO - Finished building MOR seedpoints at 162.0 Ma!
# 2025-11-29 15:49:41 - gplately - INFO - Finished building MOR seedpoints at 161.0 Ma!
# 2025-11-29 15:49:41 - gplately - INFO - Finished building MOR seedpoints at 160.0 Ma!
# 2025-11-29 15:49:50 - gplately - INFO - Finished building MOR seedpoints at 159.0 Ma!
# 2025-11-29 15:49:50 - gplately - INFO - Finished building MOR seedpoints at 158.0 Ma!
# 2025-11-29 15:49:50 - gplately - INFO - Finished building MOR seedpoints at 157.0 Ma!
# 2025-11-29 15:49:50 - gplately - INFO - Finished building MOR seedpoints at 156.0 Ma!
# 2025-11-29 15:49:51 - gplately - INFO - Finished building MOR seedpoints at 155.0 Ma!
# 2025-11-29 15:50:00 - gplately - INFO - Finished building MOR seedpoints at 154.0 Ma!
# 2025-11-29 15:50:00 - gplately - INFO - Finished building MOR seedpoints at 153.0 Ma!
# 2025-11-29 15:50:00 - gplately - INFO - Finished building MOR seedpoints at 152.0 Ma!
# 2025-11-29 15:50:00 - gplately - INFO - Finished building MOR seedpoints at 151.0 Ma!
# 2025-11-29 15:50:00 - gplately - INFO - Finished building MOR seedpoints at 150.0 Ma!
# 2025-11-29 15:49:50 - gplately - INFO - Finished building MOR seedpoints at 159.0 Ma!
# 2025-11-29 15:49:50 - gplately - INFO - Finished building MOR seedpoints at 158.0 Ma!
# 2025-11-29 15:49:50 - gplately - INFO - Finished building MOR seedpoints at 157.0 Ma!
# 2025-11-29 15:49:50 - gplately - INFO - Finished building MOR seedpoints at 156.0 Ma!
# 2025-11-29 15:49:51 - gplately - INFO - Finished building MOR seedpoints at 155.0 Ma!
# 2025-11-29 15:50:00 - gplately - INFO - Finished building MOR seedpoints at 154.0 Ma!
# 2025-11-29 15:50:00 - gplately - INFO - Finished building MOR seedpoints at 153.0 Ma!
# 2025-11-29 15:50:00 - gplately - INFO - Finished building MOR seedpoints at 152.0 Ma!
# 2025-11-29 15:50:00 - gplately - INFO - Finished building MOR seedpoints at 151.0 Ma!
# 2025-11-29 15:50:00 - gplately - INFO - Finished building MOR seedpoints at 150.0 Ma!
# 2025-11-29 15:50:09 - gplately - INFO - Finished building MOR seedpoints at 149.0 Ma!
# 2025-11-29 15:50:09 - gplately - INFO - Finished building MOR seedpoints at 148.0 Ma!
# 2025-11-29 15:50:10 - gplately - INFO - Finished building MOR seedpoints at 147.0 Ma!
# 2025-11-29 15:50:10 - gplately - INFO - Finished building MOR seedpoints at 146.0 Ma!
# 2025-11-29 15:50:10 - gplately - INFO - Finished building MOR seedpoints at 145.0 Ma!
# 2025-11-29 15:50:19 - gplately - INFO - Finished building MOR seedpoints at 144.0 Ma!
# 2025-11-29 15:50:20 - gplately - INFO - Finished building MOR seedpoints at 143.0 Ma!
# 2025-11-29 15:50:20 - gplately - INFO - Finished building MOR seedpoints at 142.0 Ma!
# 2025-11-29 15:50:20 - gplately - INFO - Finished building MOR seedpoints at 141.0 Ma!
# 2025-11-29 15:50:21 - gplately - INFO - Finished building MOR seedpoints at 140.0 Ma!
# 2025-11-29 15:50:09 - gplately - INFO - Finished building MOR seedpoints at 149.0 Ma!
# 2025-11-29 15:50:09 - gplately - INFO - Finished building MOR seedpoints at 148.0 Ma!
# 2025-11-29 15:50:10 - gplately - INFO - Finished building MOR seedpoints at 147.0 Ma!
# 2025-11-29 15:50:10 - gplately - INFO - Finished building MOR seedpoints at 146.0 Ma!
# 2025-11-29 15:50:10 - gplately - INFO - Finished building MOR seedpoints at 145.0 Ma!
# 2025-11-29 15:50:19 - gplately - INFO - Finished building MOR seedpoints at 144.0 Ma!
# 2025-11-29 15:50:20 - gplately - INFO - Finished building MOR seedpoints at 143.0 Ma!
# 2025-11-29 15:50:20 - gplately - INFO - Finished building MOR seedpoints at 142.0 Ma!
# 2025-11-29 15:50:20 - gplately - INFO - Finished building MOR seedpoints at 141.0 Ma!
# 2025-11-29 15:50:21 - gplately - INFO - Finished building MOR seedpoints at 140.0 Ma!
# 2025-11-29 15:50:29 - gplately - INFO - Finished building MOR seedpoints at 139.0 Ma!
# 2025-11-29 15:50:30 - gplately - INFO - Finished building MOR seedpoints at 138.0 Ma!
# 2025-11-29 15:50:30 - gplately - INFO - Finished building MOR seedpoints at 137.0 Ma!
# 2025-11-29 15:50:30 - gplately - INFO - Finished building MOR seedpoints at 136.0 Ma!
# 2025-11-29 15:50:31 - gplately - INFO - Finished building MOR seedpoints at 135.0 Ma!
# 2025-11-29 15:50:29 - gplately - INFO - Finished building MOR seedpoints at 139.0 Ma!
# 2025-11-29 15:50:30 - gplately - INFO - Finished building MOR seedpoints at 138.0 Ma!
# 2025-11-29 15:50:30 - gplately - INFO - Finished building MOR seedpoints at 137.0 Ma!
# 2025-11-29 15:50:30 - gplately - INFO - Finished building MOR seedpoints at 136.0 Ma!
# 2025-11-29 15:50:31 - gplately - INFO - Finished building MOR seedpoints at 135.0 Ma!
# 2025-11-29 15:50:38 - gplately - INFO - Finished building MOR seedpoints at 134.0 Ma!
# 2025-11-29 15:50:39 - gplately - INFO - Finished building MOR seedpoints at 133.0 Ma!
# 2025-11-29 15:50:39 - gplately - INFO - Finished building MOR seedpoints at 132.0 Ma!
# 2025-11-29 15:50:39 - gplately - INFO - Finished building MOR seedpoints at 131.0 Ma!
# 2025-11-29 15:50:40 - gplately - INFO - Finished building MOR seedpoints at 130.0 Ma!
# 2025-11-29 15:50:38 - gplately - INFO - Finished building MOR seedpoints at 134.0 Ma!
# 2025-11-29 15:50:39 - gplately - INFO - Finished building MOR seedpoints at 133.0 Ma!
# 2025-11-29 15:50:39 - gplately - INFO - Finished building MOR seedpoints at 132.0 Ma!
# 2025-11-29 15:50:39 - gplately - INFO - Finished building MOR seedpoints at 131.0 Ma!
# 2025-11-29 15:50:40 - gplately - INFO - Finished building MOR seedpoints at 130.0 Ma!
# 2025-11-29 15:50:48 - gplately - INFO - Finished building MOR seedpoints at 129.0 Ma!
# 2025-11-29 15:50:48 - gplately - INFO - Finished building MOR seedpoints at 128.0 Ma!
# 2025-11-29 15:50:49 - gplately - INFO - Finished building MOR seedpoints at 127.0 Ma!
# 2025-11-29 15:50:49 - gplately - INFO - Finished building MOR seedpoints at 126.0 Ma!
# 2025-11-29 15:50:49 - gplately - INFO - Finished building MOR seedpoints at 125.0 Ma!
# 2025-11-29 15:50:54 - gplately - INFO - Finished building MOR seedpoints at 124.0 Ma!
# 2025-11-29 15:50:55 - gplately - INFO - Finished building MOR seedpoints at 123.0 Ma!
# 2025-11-29 15:50:55 - gplately - INFO - Finished building MOR seedpoints at 122.0 Ma!
# 2025-11-29 15:50:56 - gplately - INFO - Finished building MOR seedpoints at 121.0 Ma!
# 2025-11-29 15:50:56 - gplately - INFO - Finished building MOR seedpoints at 120.0 Ma!
# 2025-11-29 15:50:48 - gplately - INFO - Finished building MOR seedpoints at 129.0 Ma!
# 2025-11-29 15:50:48 - gplately - INFO - Finished building MOR seedpoints at 128.0 Ma!
# 2025-11-29 15:50:49 - gplately - INFO - Finished building MOR seedpoints at 127.0 Ma!
# 2025-11-29 15:50:49 - gplately - INFO - Finished building MOR seedpoints at 126.0 Ma!
# 2025-11-29 15:50:49 - gplately - INFO - Finished building MOR seedpoints at 125.0 Ma!
# 2025-11-29 15:50:54 - gplately - INFO - Finished building MOR seedpoints at 124.0 Ma!
# 2025-11-29 15:50:55 - gplately - INFO - Finished building MOR seedpoints at 123.0 Ma!
# 2025-11-29 15:50:55 - gplately - INFO - Finished building MOR seedpoints at 122.0 Ma!
# 2025-11-29 15:50:56 - gplately - INFO - Finished building MOR seedpoints at 121.0 Ma!
# 2025-11-29 15:50:56 - gplately - INFO - Finished building MOR seedpoints at 120.0 Ma!
# 2025-11-29 15:51:04 - gplately - INFO - Finished building MOR seedpoints at 119.0 Ma!
# 2025-11-29 15:51:04 - gplately - INFO - Finished building MOR seedpoints at 118.0 Ma!
# 2025-11-29 15:51:05 - gplately - INFO - Finished building MOR seedpoints at 117.0 Ma!
# 2025-11-29 15:51:05 - gplately - INFO - Finished building MOR seedpoints at 116.0 Ma!
# 2025-11-29 15:51:05 - gplately - INFO - Finished building MOR seedpoints at 115.0 Ma!
# 2025-11-29 15:51:04 - gplately - INFO - Finished building MOR seedpoints at 119.0 Ma!
# 2025-11-29 15:51:04 - gplately - INFO - Finished building MOR seedpoints at 118.0 Ma!
# 2025-11-29 15:51:05 - gplately - INFO - Finished building MOR seedpoints at 117.0 Ma!
# 2025-11-29 15:51:05 - gplately - INFO - Finished building MOR seedpoints at 116.0 Ma!
# 2025-11-29 15:51:05 - gplately - INFO - Finished building MOR seedpoints at 115.0 Ma!
# Process SpawnPoolWorker-5:
# Process SpawnPoolWorker-8:
# Process SpawnPoolWorker-6:
# Process SpawnPoolWorker-2:
# Process SpawnPoolWorker-7:
# Process SpawnPoolWorker-9:
# Process SpawnPoolWorker-3:
# Process SpawnPoolWorker-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/queues.py", line 385, in get
#     res = self._reader.recv_bytes()
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# Process SpawnPoolWorker-4:
# Traceback (most recent call last):
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/queues.py", line 387, in get
#     return _ForkingPickler.loads(res)
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^
#   File "/Users/glados/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/reduction.py", line 225, in _rebuild_partial
#     def _rebuild_partial(func, args, keywords):
#
# KeyboardInterrupt
# 2025-11-29 15:51:14 - gplately - INFO - Finished building MOR seedpoints at 114.0 Ma!
# 2025-11-29 15:51:14 - gplately - INFO - Finished building MOR seedpoints at 113.0 Ma!
# 2025-11-29 15:51:14 - gplately - INFO - Finished building MOR seedpoints at 112.0 Ma!
# 2025-11-29 15:51:15 - gplately - INFO - Finished building MOR seedpoints at 111.0 Ma!
# 2025-11-29 15:51:15 - gplately - INFO - Finished building MOR seedpoints at 110.0 Ma!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 8
#       4 print("-" * 60)
#       6 # Generate grids using topological reconstruction
#       7 # This will create netCDF files for each time step
# ----> 8 seafloor_grid.reconstruct_by_topologies()
#      10 print("-" * 60)
#      11 print("✓ Grid generation complete!")
#
# File ~/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/site-packages/gplately/oceans.py:1183, in SeafloorGrid.reconstruct_by_topologies(self)
#    1172 logger.info("Preparing all initial files...")
#    1174 # Obtain all info from the ocean seed points and all MOR points through time, store in
#    1175 # arrays
#    1176 (
#    1177     active_points,
#    1178     appearance_time,
#    1179     birth_lat,
#    1180     prev_lat,
#    1181     prev_lon,
#    1182     zvalues,
# -> 1183 ) = self.prepare_for_reconstruction_by_topologies()
#    1185 ####  Begin reconstruction by topology process:
#    1186 # Indices for all points (`active_points`) that have existed from `max_time` to `min_time`.
#    1187 point_id = range(len(active_points))
#
# File ~/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/site-packages/gplately/oceans.py:935, in SeafloorGrid.prepare_for_reconstruction_by_topologies(self)
#     922 # MOR SEED POINTS AND CONTINENTAL MASKS --------------------------------------------
#     923
#     924 # The start time for seeding is controlled by whether the overwrite_existing_gridding_inputs
#    (...)    930 # - seeding was completed but the subsequent gridding input creation was interrupted,
#     931 # seeding is assumed completed and skipped. The workflow automatically proceeds to re-gridding.
#     933 self.build_all_continental_masks()
# --> 935 self.build_all_MOR_seedpoints()
#     937 # load the initial ocean seed points
#     938 lons = self.initial_ocean_point_df["lon"].tolist()
#
# File ~/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/site-packages/gplately/oceans.py:758, in SeafloorGrid.build_all_MOR_seedpoints(self)
#     756 if num_cpus > 1:
#     757     with multiprocessing.Pool(num_cpus) as pool:
# --> 758         pool.map(
#     759             partial(
#     760                 _generate_mid_ocean_ridge_points,
#     761                 delta_time=self._ridge_time_step,
#     762                 mid_ocean_ridges_file_path=self.mid_ocean_ridges_file_path,
#     763                 rotation_model=self.rotation_model,
#     764                 topology_features=self.topology_features,
#     765                 zvalues_file_basepath=self.zvalues_file_basepath,
#     766                 zval_names=self.zval_names,
#     767                 ridge_sampling=self.ridge_sampling,
#     768                 overwrite=overwrite,
#     769             ),
#     770             self._times[1:],
#     771         )
#     772 else:
#     773     for time in self._times[1:]:
#
# File ~/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File ~/opt/anaconda3/envs/cu-geodynamics/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     357 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     358     if timeout is None:
# --> 359         waiter.acquire()
#     360         gotit = True
#     361     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Verify Output
#
# Check that the grids were created successfully and visualize a sample time step.

# %%
# List generated files
age_grid_dir = "./seafloor-grid-output/SEAFLOOR_AGE"
if os.path.exists(age_grid_dir):
    generated_files = sorted([f for f in os.listdir(age_grid_dir) if f.endswith('.nc')])
    print(f"Generated {len(generated_files)} age grid files in {age_grid_dir}:")
    print(f"  First: {generated_files[0] if generated_files else 'None'}")
    print(f"  Last: {generated_files[-1] if generated_files else 'None'}")
else:
    print(f"⚠ Age grid directory not found: {age_grid_dir}")
    print("  Grid generation may still be in progress.")

# %%
# Load and visualize a sample grid (e.g., 100 Ma)
sample_time = 100  # Ma

# SeafloorGrid saves files in SEAFLOOR_AGE subdirectory
age_grid_dir = "./seafloor-grid-output/SEAFLOOR_AGE"
sample_filename = os.path.join(age_grid_dir, f"seafloor_age_{sample_time:.2f}Ma.nc")

if os.path.exists(sample_filename):
    # Load raster
    age_raster = gplately.Raster(filename=sample_filename)
    
    # Create figure with map projection
    fig = plt.figure(figsize=(16, 8), dpi=100)
    ax = fig.add_subplot(111, projection=ccrs.Mollweide(central_longitude=0))
    ax.set_global()
    ax.gridlines(color='0.7', linestyle='--', 
                 xlocs=np.arange(-180, 180, 30), 
                 ylocs=np.arange(-90, 90, 30))
    
    # Plot age grid
    gplot.time = sample_time
    im = gplot.plot_grid(ax, age_raster.data, cmap='YlGnBu_r', vmin=0, vmax=200)
    
    # Add plate boundaries
    gplot.plot_continents(ax, facecolor='0.8', alpha=0.3)
    gplot.plot_coastlines(ax, color='0.5', linewidth=0.5)
    gplot.plot_ridges_and_transforms(ax, color='red', linewidth=1, zorder=9)
    gplot.plot_trenches(ax, color='black', linewidth=1.5, zorder=9)
    gplot.plot_subduction_teeth(ax, color='black', zorder=10)
    
    # Colorbar
    cbar = fig.colorbar(im, ax=ax, orientation='horizontal', 
                        pad=0.05, shrink=0.6, aspect=30)
    cbar.set_label('Seafloor Age (Ma)', fontsize=12)
    
    ax.set_title(f'Seafloor Age Grid at {sample_time} Ma ({MODEL_NAME})', 
                 fontsize=14, fontweight='bold')
    
    plt.tight_layout()
    plt.show()
    
    print(f"✓ Successfully loaded and visualized {sample_filename}")
else:
    print(f"⚠ Warning: Sample file not found at {sample_filename}")
    print("   Grid generation may still be in progress or failed.")
    print(f"   Expected location: {age_grid_dir}")

# %% [markdown]
# ## Summary
#
# The generated seafloor age grids are now available in the `SEAFLOOR_AGE/` subdirectory.
#
# **Directory structure**:
# ```
# ./seafloor-grid-output/
# ├── SEAFLOOR_AGE/          # Age grids (use these!)
# ├── continent_mask/         # Continental masks for each timestep
# ├── initial_ocean_seeds/    # Initial seed points
# └── MOR_seed_points/        # Mid-ocean ridge seed points
# ```
#
# **File naming convention**: `seafloor_age_{time:.2f}Ma.nc`
#
# **Key improvements over Mather's approach**:
# 1. **Consistency**: Grids are generated from the same rotation model used for reconstruction
# 2. **Configurable**: All parameters centralized at the top for easy modification
# 3. **Documented**: Clear explanations of each step and expected runtime
# 4. **Verified**: Automatic validation and visualization of output
# 5. **Professional**: Uses GPlately's auxiliary functions and best practices

# %% [markdown]
# ## Notes for Future Use
#
# **Updating other notebooks**:
#
# To use these grids in `01-Identify-Shear-Zones.ipynb` and other workflows, update the path:
#
# ```python
# agegrid_dir = "./seafloor-grid-output/SEAFLOOR_AGE/"
# agegrid_filename = agegrid_dir + "seafloor_age_{:.2f}Ma.nc"
# ```
#
# **Important note on file naming**:
# - GPlately's `SeafloorGrid` uses `{:.2f}` format (e.g., `100.00Ma`)
# - Downloaded grids may use `{:.1f}` format (e.g., `100.0Ma`)
# - Adjust the format string in your code accordingly
#
# **Troubleshooting**:
#
# - If grids don't align with plate boundaries, ensure you're using the same model name for both grid generation and subsequent analyses
# - Check that all topologies, rotation files, and static polygons are from the same model version
# - Verify time ranges match between grid generation and reconstruction model capabilities
# - If you get permission errors, ensure the output directory has write permissions
#
# **Performance tips**:
#
# - Use multiprocessing by running as a script rather than in interactive mode
# - Reduce grid spacing (e.g., 0.5° instead of 0.1°) for faster prototyping
# - Generate grids for smaller time ranges if full coverage isn't needed
# - The process creates intermediate files (continental masks, seed points) that can be reused if interrupted
